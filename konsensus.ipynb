# %%
import dhlab as dh
import pandas as pd

# %%
corp = pd.read_excel('konsensuskorpus.xlsx')

# %%
corp
# Out:
#                                                   Verk  \
# 0    [Hvorfor har Norge ikke sit eget National-Sprog?]
# 1                                                Luren
# 2             Anmeldelse av A. Faye: Norges Historie …
# 3              Henrik Wergelands Digtekunst og Polemik
# 4    Samlinger til det norske Folks Sprog og Histor...
# ..                                                 ...
# 313                                     Familien Sterk
# 314                      Lappiske eventyr og folkesagn
# 315                                      Tvivl og Haab
# 316                               [Segner fraa Vaagaa]
# 317  Reise Erindringer og Reise-Indberetninger 1842...
#
#                         Forfatter     Utgivelsesår Jæger 1896  \
# 0                    Lundh, G. F.             1807        NaN
# 1                      Hansen, M.             1819        NaN
# 2                    Munch, P. A.             1832        NaN
# ...

# %%
corp.sample(10).values
#[corp.str.contains('x')]
# Out:
# array([['Maria', 'Welhaven, J. S.', 1838, nan, nan, nan, nan, nan, nan,
#         nan, nan, 'x, 159', nan, nan,
#         'http://urn.nb.no/URN:NBN:no-nb_digibok_2008061112002', '86-92',
#         nan, nan],
#        ['[Til og fra Amerika]', 'Meltzer, H.', '[1860]', nan, nan,
#         'x, 128', nan, nan, nan, nan, nan, nan, nan, nan,
#         'http://urn.nb.no/URN:NBN:no-nb_digibok_2017080207028', nan, nan,
#         'Opprinnelig i Aftenbladet'],
#        ['Fra Krigens Tid', 'Meltzer, H.', '[1873]', nan, nan, 'x, 128',
#         nan, nan, 'x/y, 212', nan, nan, nan, nan, nan,
#         'http://urn.nb.no/URN:NBN:no-nb_digibok_2006112201000',
#         '137-208', nan, nan],
#        ['De to Aftener', 'Moe, J.', '[1877?]', nan, nan, 'w, 122', nan,
#         nan, nan, nan, nan, nan, nan, nan,
#         'http://urn.nb.no/URN:NBN:no-nb_digibok_2011051004096',
#         '327-335', nan, nan],
#        ['Bergljot', 'Bjørnson, B.', '[1861]', nan, 'x, 198 (199)', nan,
# ...
